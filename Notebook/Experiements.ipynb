# %%
! uv pip install langchain openai tiktoken rapidocr-onnxruntime python-dotenv langchain-community
# Out:
# Using Python 3.12.12 environment at: /usr
# Resolved 72 packages in 914ms
# Prepared 13 packages in 836ms
# Uninstalled 1 package in 27ms
# Installed 13 packages in 101ms0.0
#  + coloredlogs==15.0.1
#  + dataclasses-json==0.6.7
#  + humanfriendly==10.0
#  + langchain-classic==1.0.0
#  + langchain-community==0.4.1
#  + langchain-text-splitters==1.0.0
#  + marshmallow==3.26.1
#  + mypy-extensions==1.1.0
#  + onnxruntime==1.23.2
#  + pyclipper==1.4.0
#  + rapidocr-onnxruntime==1.4.4
#  - requests==2.32.4
#  + requests==2.32.5
#  + typing-inspect==0.9.0

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# False

# %%
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-599003296.py in <cell line: 0>()
# ----> 1 os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
#
# /usr/lib/python3.12/os.py in __setitem__(self, key, value)
#
# /usr/lib/python3.12/os.py in encode(value)
#
# TypeError: str expected, not NoneType
